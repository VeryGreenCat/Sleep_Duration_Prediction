# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

# %%
df = pd.read_csv('Sleep_data__norm_ML2568.csv')

df = df.drop(df.columns[0], axis=1)  # drop col 0
df = df.drop(columns=['pid', 'date', 'date_'])  # drop non-informative columns

# %%
# CONTINUATION: target-aware imputation to fill missing target values

target_col = 'f_slp:fitbit_sleep_summary_rapids_sumdurationasleepmain_norm:allday'

# Drop rows with more than 80% missing values
row_missing_ratio = df.isna().mean(axis=1)
threshold = 0.8  # 80%
df_filtered = df.loc[row_missing_ratio <= threshold].copy()

print(f"Original rows: {len(df)}")
print(f"Remaining rows after dropping > 80% missing: {len(df_filtered)}")
print(f"dropped rows: {len(df) - len(df_filtered)}")
# Out:
# Original rows: 11470
# Remaining rows after dropping > 80% missing: 10066
# dropped rows: 1404

# %%
# Split into rows with and without target
df_with_target = df.dropna(subset=[target_col]).copy()
df_missing_target = df[df[target_col].isna()].copy()

# print size of dataset
print(f"Dataset shape: {df.shape}")
print(f"Rows with target: {len(df_with_target)} size: {df_with_target.shape}\nRows with missing target: {len(df_missing_target)} size: {df_missing_target.shape}")

# 1️⃣  Compute feature importance using Mutual Information instead of correlation
from sklearn.feature_selection import mutual_info_regression

numeric_cols = df_with_target.select_dtypes(include='number').columns.drop(target_col, errors='ignore')
X_num = df_with_target[numeric_cols].copy()
y_target = df_with_target[target_col].copy()

# Fill temporary NaNs for MI computation (MI cannot handle NaNs)
X_num_filled = X_num.fillna(X_num.median())

# Compute mutual information (nonlinear relationships)
mi_scores = mutual_info_regression(X_num_filled, y_target, random_state=42)

# Convert to Series for easier handling
mi_series = pd.Series(mi_scores, index=numeric_cols).sort_values(ascending=False)
top_features = mi_series.index[:40].tolist()

print("Top features with highest mutual information to target:")
print(top_features)

# for all these top features, check missingness in df_missing_target
print("Missingness in influential features (in rows with missing target):")
foundUsefulColumn = False
for feature in top_features:
    missing_count = df_missing_target[feature].isna().sum()
    total_count = df_missing_target.shape[0]
    missing_percentage = (missing_count / total_count * 100) if total_count > 0 else 0
    # criteria: missing less than 70% and MI > threshold
    if (missing_percentage < 70 and mi_series[feature] > 0.01):  # MI > 0.01 roughly means some relationship
        print(f"Missing in {feature}: {missing_percentage:.2f}%, mutual info: {mi_series[feature]:.4f}")
        foundUsefulColumn = True

if not foundUsefulColumn:
    print("No useful influential columns found for target imputation.")
    # Proceed with other imputation strategies 


# 2️⃣  Measure missingness in those features (in rows that have no target)
missing_counts = df_missing_target[top_features].isna().sum(axis=1)
df_missing_target['missing_in_influencers'] = missing_counts

# 3️⃣  Decide a threshold: how many influential features must be present
# Here we require that at least 80% of top_features are non-missing
threshold = int(0.7 * len(top_features))
eligible_mask = df_missing_target['missing_in_influencers'] <= (len(top_features) - threshold)
df_eligible_for_impute = df_missing_target[eligible_mask].copy()
df_drop_for_missing = df_missing_target[~eligible_mask].copy()

print(f"Eligible for target imputation: {len(df_eligible_for_impute)} rows")
print(f"Dropped (too incomplete): {len(df_drop_for_missing)} rows")

# 4️⃣  Prepare data for modeling target from top features
X_train = df_with_target[top_features].copy()
y_train = df_with_target[target_col].copy()
X_pred = df_eligible_for_impute[top_features].copy()

# Basic cleaning: impute median for feature missing values before modeling
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='median')
X_train_imputed = imputer.fit_transform(X_train)
X_pred_imputed = imputer.transform(X_pred)

# 5️⃣  Train a regression model to predict target for missing rows
from sklearn.ensemble import RandomForestRegressor

rf_imputer = RandomForestRegressor(
    n_estimators=200,
    random_state=42,
    n_jobs=-1,
    max_depth=10
)
rf_imputer.fit(X_train_imputed, y_train)

# 6️⃣  Predict missing targets
predicted_targets = rf_imputer.predict(X_pred_imputed)
df_eligible_for_impute[target_col] = predicted_targets
df_eligible_for_impute['target_imputed'] = True

# 7️⃣  Combine back into one DataFrame
df_with_target['target_imputed'] = False
df_filled = pd.concat([df_with_target, df_eligible_for_impute], ignore_index=True)

print(f"Final data size after imputation: {len(df_filled)}")
print(f"Rows with actual targets: {(~df_filled['target_imputed']).sum()}")
print(f"Rows with imputed targets: {df_filled['target_imputed'].sum()}")

# 8️⃣  Optional sanity check — compare distributions
plt.figure(figsize=(8,4))
plt.hist(df_with_target[target_col], bins=40, alpha=0.6, label='Original target')
plt.hist(predicted_targets, bins=40, alpha=0.6, label='Imputed target')
plt.xlabel('Sleep duration (normalized)')
plt.ylabel('Frequency')
plt.legend()
plt.title('Distribution: Original vs Imputed Target')
plt.show()

# df_filled is now your main dataset with both original and imputed targets
# Out:
# Dataset shape: (11470, 139)
# Rows with target: 7336 size: (7336, 139)
# Rows with missing target: 4134 size: (4134, 139)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 19
#      16 # Fill temporary NaNs for MI computation (MI cannot handle NaNs)
#      17 X_num_filled = X_num.fillna(X_num.median())
# ---> 19 mi_scores = mutual_info_regression(X_num_filled, y_target, random_state=42)
#      21 # Convert to Series for easier handling
#      22 mi_series = pd.Series(mi_scores, index=numeric_cols).sort_values(ascending=False)
#
# File d:\Python\Sleep_Duration_Prediction\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File d:\Python\Sleep_Duration_Prediction\.venv\Lib\site-packages\sklearn\feature_selection\_mutual_info.py:441, in mutual_info_regression(X, y, discrete_features, n_neighbors, copy, random_state, n_jobs)
#     325 @validate_params(
#     326     {
#     327         "X": ["array-like", "sparse matrix"],
#    (...)    345     n_jobs=None,
#     346 ):
#     347     """Estimate mutual information for a continuous target variable.
#     348
#     349     Mutual information (MI) [1]_ between two random variables is a non-negative
#    (...)    439     array([0.117, 2.645, 0.0287])
#     440     """
# --> 441     return _estimate_mi(
#     442         X,
#     443         y,
#     444         discrete_features=discrete_features,
#     445         discrete_target=False,
#     446         n_neighbors=n_neighbors,
#     447         copy=copy,
#     448         random_state=random_state,
#     449         n_jobs=n_jobs,
#     450     )
#
# File d:\Python\Sleep_Duration_Prediction\.venv\Lib\site-packages\sklearn\feature_selection\_mutual_info.py:271, in _estimate_mi(X, y, discrete_features, discrete_target, n_neighbors, copy, random_state, n_jobs)
#     202 def _estimate_mi(
#     203     X,
#     204     y,
#    (...)    211     n_jobs=None,
#     212 ):
#     213     """Estimate mutual information between the features and the target.
#     214
#     215     Parameters
#    (...)    269            Data Sets". PLoS ONE 9(2), 2014.
#     270     """
# --> 271     X, y = check_X_y(X, y, accept_sparse="csc", y_numeric=not discrete_target)
#     272     n_samples, n_features = X.shape
#     274     if isinstance(discrete_features, (str, bool)):
#
# File d:\Python\Sleep_Duration_Prediction\.venv\Lib\site-packages\sklearn\utils\validation.py:1368, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1362     raise ValueError(
#    1363         f"{estimator_name} requires y to be passed, but the target y is None"
#    1364     )
#    1366 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
# -> 1368 X = check_array(
#    1369     X,
#    1370     accept_sparse=accept_sparse,
#    1371     accept_large_sparse=accept_large_sparse,
#    1372     dtype=dtype,
#    1373     order=order,
#    1374     copy=copy,
#    1375     force_writeable=force_writeable,
#    1376     ensure_all_finite=ensure_all_finite,
#    1377     ensure_2d=ensure_2d,
#    1378     allow_nd=allow_nd,
#    1379     ensure_min_samples=ensure_min_samples,
#    1380     ensure_min_features=ensure_min_features,
#    1381     estimator=estimator,
#    1382     input_name="X",
#    1383 )
#    1385 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1387 check_consistent_length(X, y)
#
# File d:\Python\Sleep_Duration_Prediction\.venv\Lib\site-packages\sklearn\utils\validation.py:1105, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1099     raise ValueError(
#    1100         f"Found array with dim {array.ndim},"
#    1101         f" while dim <= 2 is required{context}."
#    1102     )
#    1104 if ensure_all_finite:
# -> 1105     _assert_all_finite(
#    1106         array,
#    1107         input_name=input_name,
#    1108         estimator_name=estimator_name,
#    1109         allow_nan=ensure_all_finite == "allow-nan",
#    1110     )
#    1112 if copy:
#    1113     if _is_numpy_namespace(xp):
#    1114         # only make a copy if `array` and `array_orig` may share memory`
#
# File d:\Python\Sleep_Duration_Prediction\.venv\Lib\site-packages\sklearn\utils\validation.py:120, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     117 if first_pass_isfinite:
#     118     return
# --> 120 _assert_all_finite_element_wise(
#     121     X,
#     122     xp=xp,
#     123     allow_nan=allow_nan,
#     124     msg_dtype=msg_dtype,
#     125     estimator_name=estimator_name,
#     126     input_name=input_name,
#     127 )
#
# File d:\Python\Sleep_Duration_Prediction\.venv\Lib\site-packages\sklearn\utils\validation.py:169, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     152 if estimator_name and input_name == "X" and has_nan_error:
#     153     # Improve the error message on how to handle missing values in
#     154     # scikit-learn.
#     155     msg_err += (
#     156         f"\n{estimator_name} does not accept missing values"
#     157         " encoded as NaN natively. For supervised learning, you might want"
#    (...)    167         "#estimators-that-handle-nan-values"
#     168     )
# --> 169 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
for col in [c for c in df.columns if 'screen' in c]:
    corr = df.corr(numeric_only=True)[col].sort_values(ascending=False)
    print(f"\nTop correlations with {col}:\n", corr[1:6])
# Out:
# Top correlations with f_screen:phone_screen_rapids_countepisodeunlock_norm:afternoon:
#  f_screen:phone_screen_rapids_countepisodeunlock_norm:allday      0.764269
# f_screen:phone_screen_rapids_countepisodeunlock_norm:evening     0.309548
# f_screen:phone_screen_rapids_countepisodeunlock_norm:morning     0.298422
# f_blue:phone_bluetooth_doryab_uniquedevicesall_norm:allday       0.274187
# f_blue:phone_bluetooth_doryab_uniquedevicesall_norm:afternoon    0.253772
# Name: f_screen:phone_screen_rapids_countepisodeunlock_norm:afternoon, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_norm:afternoon:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:afternoon      0.583025
# f_screen:phone_screen_rapids_sumdurationunlock_norm:allday                     0.497595
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:afternoon    0.496432
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:allday         0.306515
# f_screen:phone_screen_rapids_sumdurationunlock_norm:evening                    0.273864
# Name: f_screen:phone_screen_rapids_sumdurationunlock_norm:afternoon, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise_norm:afternoon:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise_norm:allday    0.732453
# f_loc:phone_locations_locmap_duration_in_locmap_exercise_norm:afternoon       0.499395
# f_loc:phone_locations_locmap_duration_in_locmap_exercise_norm:allday          0.399210
# f_call:phone_calls_rapids_incoming_count_norm:morning                         0.207584
# f_steps:fitbit_steps_intraday_rapids_sumdurationactivebout_norm:afternoon     0.189413
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise_norm:afternoon, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens_norm:afternoon:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens_norm:allday    0.771632
# f_loc:phone_locations_locmap_duration_in_locmap_greens_norm:afternoon       0.621134
# f_loc:phone_locations_locmap_duration_in_locmap_greens_norm:allday          0.483244
# f_screen:phone_screen_rapids_sumdurationunlock_norm:afternoon               0.229091
# f_screen:phone_screen_rapids_sumdurationunlock_norm:allday                  0.141125
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens_norm:afternoon, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:afternoon:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:afternoon    0.776170
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:allday     0.611670
# f_screen:phone_screen_rapids_sumdurationunlock_norm:afternoon                0.496432
# f_loc:phone_locations_doryab_timeathome_norm:afternoon                       0.467127
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:allday       0.463087
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:afternoon, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_study_norm:afternoon:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_study_norm:allday    0.725706
# f_loc:phone_locations_locmap_duration_in_locmap_study_norm:afternoon       0.601529
# f_loc:phone_locations_locmap_duration_in_locmap_study_norm:allday          0.425115
# f_screen:phone_screen_rapids_sumdurationunlock_norm:afternoon              0.227981
# f_screen:phone_screen_rapids_sumdurationunlock_norm:allday                 0.136814
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_study_norm:afternoon, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:afternoon:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:afternoon    0.776170
# f_loc:phone_locations_doryab_timeathome_norm:afternoon                         0.654496
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:allday         0.622057
# f_screen:phone_screen_rapids_sumdurationunlock_norm:afternoon                  0.583025
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:allday       0.435913
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:afternoon, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_countepisodeunlock_norm:allday:
#  f_screen:phone_screen_rapids_countepisodeunlock_norm:afternoon    0.764269
# f_screen:phone_screen_rapids_countepisodeunlock_norm:evening      0.684334
# f_screen:phone_screen_rapids_countepisodeunlock_norm:morning      0.546394
# f_blue:phone_bluetooth_doryab_uniquedevicesall_norm:allday        0.365900
# f_screen:phone_screen_rapids_sumdurationunlock_norm:allday        0.356328
# Name: f_screen:phone_screen_rapids_countepisodeunlock_norm:allday, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_norm:allday:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:allday      0.659322
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:allday    0.546581
# f_screen:phone_screen_rapids_sumdurationunlock_norm:evening                 0.522843
# f_screen:phone_screen_rapids_sumdurationunlock_norm:afternoon               0.497595
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:evening     0.428610
# Name: f_screen:phone_screen_rapids_sumdurationunlock_norm:allday, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise_norm:allday:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise_norm:afternoon    0.732453
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise_norm:evening      0.708601
# f_loc:phone_locations_locmap_duration_in_locmap_exercise_norm:allday             0.553168
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise_norm:night        0.506022
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise_norm:morning      0.480643
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise_norm:allday, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens_norm:allday:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens_norm:afternoon    0.771632
# f_loc:phone_locations_locmap_duration_in_locmap_greens_norm:allday             0.662852
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens_norm:evening      0.584685
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens_norm:morning      0.538734
# f_loc:phone_locations_locmap_duration_in_locmap_greens_norm:afternoon          0.509593
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens_norm:allday, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:allday:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:allday         0.716268
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:evening      0.635791
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:afternoon    0.611670
# f_screen:phone_screen_rapids_sumdurationunlock_norm:allday                     0.546581
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:evening        0.456448
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:allday, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_study_norm:allday:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_study_norm:afternoon    0.725706
# f_loc:phone_locations_locmap_duration_in_locmap_study_norm:allday             0.638546
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_study_norm:morning      0.583538
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_study_norm:evening      0.575527
# f_loc:phone_locations_locmap_duration_in_locmap_study_norm:afternoon          0.486445
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_study_norm:allday, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:allday:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:allday     0.716268
# f_screen:phone_screen_rapids_sumdurationunlock_norm:allday                   0.659322
# f_loc:phone_locations_doryab_timeathome_norm:allday                          0.646516
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:evening      0.629794
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:afternoon    0.622057
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:allday, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_countepisodeunlock_norm:evening:
#  f_screen:phone_screen_rapids_countepisodeunlock_norm:allday       0.684334
# f_screen:phone_screen_rapids_countepisodeunlock_norm:afternoon    0.309548
# f_blue:phone_bluetooth_doryab_uniquedevicesall_norm:evening       0.239100
# f_blue:phone_bluetooth_doryab_uniquedevicesall_norm:allday        0.214292
# f_call:phone_calls_rapids_outgoing_count_norm:evening             0.189255
# Name: f_screen:phone_screen_rapids_countepisodeunlock_norm:evening, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_norm:evening:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:evening      0.628524
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:evening    0.549284
# f_screen:phone_screen_rapids_sumdurationunlock_norm:allday                   0.522843
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:allday       0.320178
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:allday     0.290913
# Name: f_screen:phone_screen_rapids_sumdurationunlock_norm:evening, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise_norm:evening:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise_norm:allday     0.708601
# f_loc:phone_locations_locmap_duration_in_locmap_exercise_norm:evening          0.420906
# f_loc:phone_locations_locmap_duration_in_locmap_exercise_norm:allday           0.348124
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise_norm:morning    0.194344
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise_norm:night      0.159735
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise_norm:evening, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens_norm:evening:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens_norm:allday    0.584685
# f_loc:phone_locations_locmap_duration_in_locmap_greens_norm:evening         0.576536
# f_loc:phone_locations_locmap_duration_in_locmap_greens_norm:allday          0.386965
# f_screen:phone_screen_rapids_sumdurationunlock_norm:evening                 0.202023
# f_call:phone_calls_rapids_incoming_sumduration_norm:night                   0.149256
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens_norm:evening, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:evening:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:evening     0.768333
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:allday    0.635791
# f_screen:phone_screen_rapids_sumdurationunlock_norm:evening                 0.549284
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:allday      0.461316
# f_loc:phone_locations_doryab_timeathome_norm:evening                        0.389492
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:evening, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_study_norm:evening:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_study_norm:allday    0.575527
# f_loc:phone_locations_locmap_duration_in_locmap_study_norm:evening         0.548076
# f_loc:phone_locations_locmap_duration_in_locmap_study_norm:allday          0.412727
# f_loc:phone_locations_doryab_movingtostaticratio_norm:evening              0.157808
# f_screen:phone_screen_rapids_sumdurationunlock_norm:evening                0.140317
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_study_norm:evening, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:evening:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:evening    0.768333
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:allday       0.629794
# f_screen:phone_screen_rapids_sumdurationunlock_norm:evening                  0.628524
# f_loc:phone_locations_doryab_timeathome_norm:evening                         0.573287
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:allday     0.456448
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:evening, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_countepisodeunlock_norm:morning:
#  f_screen:phone_screen_rapids_countepisodeunlock_norm:allday                0.546394
# f_steps:fitbit_steps_intraday_rapids_sumsteps_norm:morning                 0.368969
# f_steps:fitbit_steps_intraday_rapids_sumdurationactivebout_norm:morning    0.361853
# f_blue:phone_bluetooth_doryab_uniquedevicesall_norm:morning                0.337446
# f_loc:phone_locations_doryab_totaldistance_norm:morning                    0.326880
# Name: f_screen:phone_screen_rapids_countepisodeunlock_norm:morning, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_norm:morning:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:morning      0.540253
# f_screen:phone_screen_rapids_sumdurationunlock_norm:night                    0.533625
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:morning    0.518794
# f_screen:phone_screen_rapids_sumdurationunlock_norm:afternoon                0.273849
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_study_norm:morning     0.230315
# Name: f_screen:phone_screen_rapids_sumdurationunlock_norm:morning, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise_norm:morning:
#  f_call:phone_calls_rapids_incoming_sumduration_norm:night                     0.498601
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise_norm:allday    0.480643
# f_loc:phone_locations_locmap_duration_in_locmap_exercise_norm:morning         0.378275
# f_call:phone_calls_rapids_missed_count_norm:night                             0.309405
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise_norm:night     0.263359
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise_norm:morning, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens_norm:morning:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens_norm:allday    0.538734
# f_loc:phone_locations_locmap_duration_in_locmap_greens_norm:morning         0.509208
# f_loc:phone_locations_locmap_duration_in_locmap_greens_norm:allday          0.325688
# f_screen:phone_screen_rapids_sumdurationunlock_norm:morning                 0.181149
# f_call:phone_calls_rapids_incoming_sumduration_norm:night                   0.168816
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens_norm:morning, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:morning:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:morning     0.855502
# f_screen:phone_screen_rapids_sumdurationunlock_norm:morning                 0.518794
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:allday    0.398242
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:allday      0.342010
# f_loc:phone_locations_doryab_timeathome_norm:morning                        0.308468
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:morning, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_study_norm:morning:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_study_norm:allday    0.583538
# f_loc:phone_locations_locmap_duration_in_locmap_study_norm:morning         0.483430
# f_loc:phone_locations_locmap_duration_in_locmap_study_norm:allday          0.273349
# f_screen:phone_screen_rapids_sumdurationunlock_norm:morning                0.230315
# f_screen:phone_screen_rapids_countepisodeunlock_norm:morning               0.143901
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_study_norm:morning, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:morning:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:morning    0.855502
# f_screen:phone_screen_rapids_sumdurationunlock_norm:morning                  0.540253
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:allday       0.406887
# f_loc:phone_locations_doryab_timeathome_norm:morning                         0.390042
# f_screen:phone_screen_rapids_sumdurationunlock_norm:allday                   0.311207
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:morning, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_countepisodeunlock_norm:night:
#  f_steps:fitbit_steps_intraday_rapids_countepisodeactivebout_norm:night    0.370845
# f_steps:fitbit_steps_intraday_rapids_sumdurationactivebout_norm:night     0.358218
# f_steps:fitbit_steps_intraday_rapids_sumsteps_norm:night                  0.351263
# f_screen:phone_screen_rapids_countepisodeunlock_norm:allday               0.287254
# f_loc:phone_locations_doryab_totaldistance_norm:night                     0.259148
# Name: f_screen:phone_screen_rapids_countepisodeunlock_norm:night, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_norm:night:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:night      0.735081
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:night    0.702258
# f_screen:phone_screen_rapids_sumdurationunlock_norm:morning                0.533625
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens_norm:night    0.348115
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_study_norm:night     0.285938
# Name: f_screen:phone_screen_rapids_sumdurationunlock_norm:night, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise_norm:night:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise_norm:allday    0.506022
# f_call:phone_calls_rapids_outgoing_sumduration_norm:night                     0.428541
# f_loc:phone_locations_locmap_duration_in_locmap_exercise_norm:allday          0.420311
# f_loc:phone_locations_locmap_duration_in_locmap_exercise_norm:night           0.283075
# f_loc:phone_locations_locmap_duration_in_locmap_exercise_norm:morning         0.273013
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise_norm:night, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens_norm:night:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:night       0.440447
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens_norm:allday    0.357715
# f_call:phone_calls_rapids_missed_count_norm:morning                         0.352622
# f_screen:phone_screen_rapids_sumdurationunlock_norm:night                   0.348115
# f_call:phone_calls_rapids_outgoing_count_norm:night                         0.229884
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens_norm:night, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:night:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:night       0.873180
# f_screen:phone_screen_rapids_sumdurationunlock_norm:night                   0.702258
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:allday    0.412280
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:allday      0.355850
# f_screen:phone_screen_rapids_sumdurationunlock_norm:allday                  0.323064
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:night, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_study_norm:night:
#  f_call:phone_calls_rapids_incoming_sumduration_norm:night                  0.450039
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_study_norm:allday    0.418140
# f_call:phone_calls_rapids_outgoing_count_norm:night                        0.324379
# f_screen:phone_screen_rapids_sumdurationunlock_norm:night                  0.285938
# f_loc:phone_locations_locmap_duration_in_locmap_study_norm:night           0.282985
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_study_norm:night, dtype: float64
#
# Top correlations with f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:night:
#  f_screen:phone_screen_rapids_sumdurationunlock_locmap_living_norm:night    0.873180
# f_screen:phone_screen_rapids_sumdurationunlock_norm:night                  0.735081
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens_norm:night    0.440447
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:allday     0.407414
# f_screen:phone_screen_rapids_sumdurationunlock_norm:allday                 0.358442
# Name: f_screen:phone_screen_rapids_sumdurationunlock_locmap_home_norm:night, dtype: float64

# %%
def count_missing_values(data, columns=None):
    # If no specific columns provided, use all columns
    if columns is None:
        columns = data.columns
    
    # Count missing values for specified columns
    missing_counts = data[columns].isnull().sum()
    
    # Add percentage of missing values
    missing_percentage = (missing_counts / len(data)) * 100
    
    # Create a DataFrame with both counts and percentages
    missing_info = pd.DataFrame({
        'Missing Count': missing_counts,
        'Missing Percentage': missing_percentage
    })
    
    return missing_info.sort_values('Missing Count', ascending=False)

# %%
missing_stats = count_missing_values(df)
display(missing_stats)
# Out:
#                                                     Missing Count  \
# f_loc:phone_locations_barnett_hometime_norm:mor...          11470
# f_loc:phone_locations_barnett_circdnrtn_norm:af...          11470
# f_loc:phone_locations_barnett_rog_norm:afternoon            11470
# f_loc:phone_locations_barnett_siglocsvisited_no...          11470
# f_loc:phone_locations_barnett_wkenddayrtn_norm:...          11470
# ...                                                           ...
# f_loc:phone_locations_doryab_totaldistance_norm...           1406
# Unnamed: 0                                                      0
# pid                                                             0
# date                                                            0
# date_                                                           0
#
#                                                     Missing Percentage
# f_loc:phone_locations_barnett_hometime_norm:mor...          100.000000
# f_loc:phone_locations_barnett_circdnrtn_norm:af...          100.000000
# f_loc:phone_locations_barnett_rog_norm:afternoon            100.000000
# f_loc:phone_locations_barnett_siglocsvisited_no...          100.000000
# f_loc:phone_locations_barnett_wkenddayrtn_norm:...          100.000000
# ...                                                                ...
# f_loc:phone_locations_doryab_totaldistance_norm...           12.258065
# Unnamed: 0                                                    0.000000
# pid                                                           0.000000
# date                                                          0.000000
# date_                                                         0.000000
#
# [143 rows x 2 columns]

# %%
# drop col with more than 70% missing values
threshold = 0.7  # 70%
missing_rate = df.isnull().mean()
to_drop = missing_rate[missing_rate > threshold].index
df = df.drop(columns=to_drop)

# %%
missing_stats = count_missing_values(df.filter(like='f_loc'))
display(missing_stats)
# Out:
#                                                     Missing Count  \
# f_loc:phone_locations_locmap_duration_in_locmap...           2431
# f_loc:phone_locations_locmap_duration_in_locmap...           2431
# f_loc:phone_locations_locmap_duration_in_locmap...           2431
# f_loc:phone_locations_doryab_totaldistance_norm...           2431
# f_loc:phone_locations_doryab_timeathome_norm:night           2431
# f_loc:phone_locations_doryab_movingtostaticrati...           2431
# f_loc:phone_locations_doryab_movingtostaticrati...           1930
# f_loc:phone_locations_doryab_timeathome_norm:mo...           1930
# f_loc:phone_locations_doryab_totaldistance_norm...           1929
# f_loc:phone_locations_locmap_duration_in_locmap...           1929
# f_loc:phone_locations_locmap_duration_in_locmap...           1929
# f_loc:phone_locations_locmap_duration_in_locmap...           1929
# f_loc:phone_locations_doryab_timeathome_norm:ev...           1796
# f_loc:phone_locations_locmap_duration_in_locmap...           1796
# f_loc:phone_locations_locmap_duration_in_locmap...           1796
# f_loc:phone_locations_locmap_duration_in_locmap...           1796
# f_loc:phone_locations_doryab_totaldistance_norm...           1796
# f_loc:phone_locations_doryab_movingtostaticrati...           1796
# f_loc:phone_locations_doryab_timeathome_norm:af...           1675
# f_loc:phone_locations_locmap_duration_in_locmap...           1675
# f_loc:phone_locations_doryab_totaldistance_norm...           1675
# f_loc:phone_locations_locmap_duration_in_locmap...           1675
# f_loc:phone_locations_locmap_duration_in_locmap...           1675
# f_loc:phone_locations_doryab_movingtostaticrati...           1675
# f_loc:phone_locations_barnett_wkenddayrtn_norm:...           1419
# f_loc:phone_locations_barnett_circdnrtn_norm:al...           1419
# f_loc:phone_locations_barnett_rog_norm:allday                1418
# f_loc:phone_locations_barnett_hometime_norm:allday           1418
# f_loc:phone_locations_barnett_siglocsvisited_no...           1418
# f_loc:phone_locations_doryab_movingtostaticrati...           1406
# f_loc:phone_locations_locmap_duration_in_locmap...           1406
# f_loc:phone_locations_doryab_timeathome_norm:al...           1406
# f_loc:phone_locations_doryab_totaldistance_norm...           1406
# f_loc:phone_locations_locmap_duration_in_locmap...           1406
# f_loc:phone_locations_locmap_duration_in_locmap...           1406
#
#                                                     Missing Percentage
# f_loc:phone_locations_locmap_duration_in_locmap...           21.194420
# f_loc:phone_locations_locmap_duration_in_locmap...           21.194420
# f_loc:phone_locations_locmap_duration_in_locmap...           21.194420
# f_loc:phone_locations_doryab_totaldistance_norm...           21.194420
# f_loc:phone_locations_doryab_timeathome_norm:night           21.194420
# f_loc:phone_locations_doryab_movingtostaticrati...           21.194420
# f_loc:phone_locations_doryab_movingtostaticrati...           16.826504
# f_loc:phone_locations_doryab_timeathome_norm:mo...           16.826504
# f_loc:phone_locations_doryab_totaldistance_norm...           16.817786
# f_loc:phone_locations_locmap_duration_in_locmap...           16.817786
# f_loc:phone_locations_locmap_duration_in_locmap...           16.817786
# f_loc:phone_locations_locmap_duration_in_locmap...           16.817786
# f_loc:phone_locations_doryab_timeathome_norm:ev...           15.658239
# f_loc:phone_locations_locmap_duration_in_locmap...           15.658239
# f_loc:phone_locations_locmap_duration_in_locmap...           15.658239
# f_loc:phone_locations_locmap_duration_in_locmap...           15.658239
# f_loc:phone_locations_doryab_totaldistance_norm...           15.658239
# f_loc:phone_locations_doryab_movingtostaticrati...           15.658239
# f_loc:phone_locations_doryab_timeathome_norm:af...           14.603313
# f_loc:phone_locations_locmap_duration_in_locmap...           14.603313
# f_loc:phone_locations_doryab_totaldistance_norm...           14.603313
# f_loc:phone_locations_locmap_duration_in_locmap...           14.603313
# f_loc:phone_locations_locmap_duration_in_locmap...           14.603313
# f_loc:phone_locations_doryab_movingtostaticrati...           14.603313
# f_loc:phone_locations_barnett_wkenddayrtn_norm:...           12.371404
# f_loc:phone_locations_barnett_circdnrtn_norm:al...           12.371404
# f_loc:phone_locations_barnett_rog_norm:allday                12.362685
# f_loc:phone_locations_barnett_hometime_norm:allday           12.362685
# f_loc:phone_locations_barnett_siglocsvisited_no...           12.362685
# f_loc:phone_locations_doryab_movingtostaticrati...           12.258065
# f_loc:phone_locations_locmap_duration_in_locmap...           12.258065
# f_loc:phone_locations_doryab_timeathome_norm:al...           12.258065
# f_loc:phone_locations_doryab_totaldistance_norm...           12.258065
# f_loc:phone_locations_locmap_duration_in_locmap...           12.258065
# f_loc:phone_locations_locmap_duration_in_locmap...           12.258065

# %%
missing_stats = count_missing_values(df.filter(like='f_screen'))
display(missing_stats)
# Out:
#                                                     Missing Count  \
# f_screen:phone_screen_rapids_sumdurationunlock_...           7876
# f_screen:phone_screen_rapids_sumdurationunlock_...           7309
# f_screen:phone_screen_rapids_sumdurationunlock_...           6826
# f_screen:phone_screen_rapids_sumdurationunlock_...           6427
# f_screen:phone_screen_rapids_sumdurationunlock_...           6254
# f_screen:phone_screen_rapids_sumdurationunlock_...           5823
# f_screen:phone_screen_rapids_sumdurationunlock_...           5507
# f_screen:phone_screen_rapids_sumdurationunlock_...           5349
# f_screen:phone_screen_rapids_sumdurationunlock_...           5278
# f_screen:phone_screen_rapids_sumdurationunlock_...           4778
# f_screen:phone_screen_rapids_sumdurationunlock_...           4154
# f_screen:phone_screen_rapids_sumdurationunlock_...           4101
# f_screen:phone_screen_rapids_sumdurationunlock_...           4075
# f_screen:phone_screen_rapids_sumdurationunlock_...           3675
# f_screen:phone_screen_rapids_countepisodeunlock...           3675
# f_screen:phone_screen_rapids_sumdurationunlock_...           3550
# f_screen:phone_screen_rapids_sumdurationunlock_...           2328
# f_screen:phone_screen_rapids_countepisodeunlock...           2096
# f_screen:phone_screen_rapids_sumdurationunlock_...           2096
# f_screen:phone_screen_rapids_countepisodeunlock...           1770
# f_screen:phone_screen_rapids_sumdurationunlock_...           1770
# f_screen:phone_screen_rapids_sumdurationunlock_...           1631
# f_screen:phone_screen_rapids_countepisodeunlock...           1631
# f_screen:phone_screen_rapids_sumdurationunlock_...           1439
# f_screen:phone_screen_rapids_countepisodeunlock...           1439
#
#                                                     Missing Percentage
# f_screen:phone_screen_rapids_sumdurationunlock_...           68.666085
# f_screen:phone_screen_rapids_sumdurationunlock_...           63.722755
# f_screen:phone_screen_rapids_sumdurationunlock_...           59.511770
# f_screen:phone_screen_rapids_sumdurationunlock_...           56.033130
# f_screen:phone_screen_rapids_sumdurationunlock_...           54.524847
# f_screen:phone_screen_rapids_sumdurationunlock_...           50.767219
# f_screen:phone_screen_rapids_sumdurationunlock_...           48.012206
# f_screen:phone_screen_rapids_sumdurationunlock_...           46.634699
# f_screen:phone_screen_rapids_sumdurationunlock_...           46.015693
# f_screen:phone_screen_rapids_sumdurationunlock_...           41.656495
# f_screen:phone_screen_rapids_sumdurationunlock_...           36.216216
# f_screen:phone_screen_rapids_sumdurationunlock_...           35.754141
# f_screen:phone_screen_rapids_sumdurationunlock_...           35.527463
# f_screen:phone_screen_rapids_sumdurationunlock_...           32.040105
# f_screen:phone_screen_rapids_countepisodeunlock...           32.040105
# f_screen:phone_screen_rapids_sumdurationunlock_...           30.950305
# f_screen:phone_screen_rapids_sumdurationunlock_...           20.296425
# f_screen:phone_screen_rapids_countepisodeunlock...           18.273758
# f_screen:phone_screen_rapids_sumdurationunlock_...           18.273758
# f_screen:phone_screen_rapids_countepisodeunlock...           15.431561
# f_screen:phone_screen_rapids_sumdurationunlock_...           15.431561
# f_screen:phone_screen_rapids_sumdurationunlock_...           14.219704
# f_screen:phone_screen_rapids_countepisodeunlock...           14.219704
# f_screen:phone_screen_rapids_sumdurationunlock_...           12.545772
# f_screen:phone_screen_rapids_countepisodeunlock...           12.545772

# %%
missing_stats = count_missing_values(df.filter(like='f_call'))
display(missing_stats)
# Out:
#                                                     Missing Count  \
# f_call:phone_calls_rapids_missed_count_norm:allday           7305
# f_call:phone_calls_rapids_incoming_count_norm:a...           7305
# f_call:phone_calls_rapids_outgoing_count_norm:a...           7305
#
#                                                     Missing Percentage
# f_call:phone_calls_rapids_missed_count_norm:allday           63.687881
# f_call:phone_calls_rapids_incoming_count_norm:a...           63.687881
# f_call:phone_calls_rapids_outgoing_count_norm:a...           63.687881

# %%
missing_stats = count_missing_values(df.filter(like='f_blue'))
display(missing_stats)
# Out:
#                                                     Missing Count  \
# f_blue:phone_bluetooth_doryab_uniquedevicesall_...           6069
# f_blue:phone_bluetooth_doryab_uniquedevicesall_...           3909
# f_blue:phone_bluetooth_doryab_uniquedevicesall_...           3508
# f_blue:phone_bluetooth_doryab_uniquedevicesall_...           2769
# f_blue:phone_bluetooth_doryab_uniquedevicesall_...           1892
#
#                                                     Missing Percentage
# f_blue:phone_bluetooth_doryab_uniquedevicesall_...           52.911944
# f_blue:phone_bluetooth_doryab_uniquedevicesall_...           34.080209
# f_blue:phone_bluetooth_doryab_uniquedevicesall_...           30.584133
# f_blue:phone_bluetooth_doryab_uniquedevicesall_...           24.141238
# f_blue:phone_bluetooth_doryab_uniquedevicesall_...           16.495205

# %%
missing_stats = count_missing_values(df.filter(like='f_steps'))
display(missing_stats)
# Out:
#                                                     Missing Count  \
# f_steps:fitbit_steps_intraday_rapids_countepiso...           5323
# f_steps:fitbit_steps_intraday_rapids_sumduratio...           5323
# f_steps:fitbit_steps_intraday_rapids_countepiso...           4074
# f_steps:fitbit_steps_intraday_rapids_sumduratio...           4074
# f_steps:fitbit_steps_intraday_rapids_countepiso...           3796
# f_steps:fitbit_steps_intraday_rapids_sumduratio...           3796
# f_steps:fitbit_steps_intraday_rapids_countepiso...           3703
# f_steps:fitbit_steps_intraday_rapids_sumduratio...           3703
# f_steps:fitbit_steps_intraday_rapids_sumsteps_n...           3397
# f_steps:fitbit_steps_intraday_rapids_sumsteps_n...           3397
# f_steps:fitbit_steps_intraday_rapids_countepiso...           3397
# f_steps:fitbit_steps_intraday_rapids_sumduratio...           3397
# f_steps:fitbit_steps_intraday_rapids_sumsteps_n...           3397
# f_steps:fitbit_steps_intraday_rapids_sumsteps_n...           3397
# f_steps:fitbit_steps_intraday_rapids_sumsteps_n...           3397
#
#                                                     Missing Percentage
# f_steps:fitbit_steps_intraday_rapids_countepiso...           46.408021
# f_steps:fitbit_steps_intraday_rapids_sumduratio...           46.408021
# f_steps:fitbit_steps_intraday_rapids_countepiso...           35.518745
# f_steps:fitbit_steps_intraday_rapids_sumduratio...           35.518745
# f_steps:fitbit_steps_intraday_rapids_countepiso...           33.095031
# f_steps:fitbit_steps_intraday_rapids_sumduratio...           33.095031
# f_steps:fitbit_steps_intraday_rapids_countepiso...           32.284220
# f_steps:fitbit_steps_intraday_rapids_sumduratio...           32.284220
# f_steps:fitbit_steps_intraday_rapids_sumsteps_n...           29.616391
# f_steps:fitbit_steps_intraday_rapids_sumsteps_n...           29.616391
# f_steps:fitbit_steps_intraday_rapids_countepiso...           29.616391
# f_steps:fitbit_steps_intraday_rapids_sumduratio...           29.616391
# f_steps:fitbit_steps_intraday_rapids_sumsteps_n...           29.616391
# f_steps:fitbit_steps_intraday_rapids_sumsteps_n...           29.616391
# f_steps:fitbit_steps_intraday_rapids_sumsteps_n...           29.616391

# %%
missing_stats = count_missing_values(df.filter(like='f_slp'))
display(missing_stats)
# Out:
#                                                     Missing Count  \
# f_slp:fitbit_sleep_summary_rapids_avgefficiency...           4214
# f_slp:fitbit_sleep_summary_rapids_avgefficiency...           4214
# f_slp:fitbit_sleep_summary_rapids_sumdurationas...           4134
# f_slp:fitbit_sleep_summary_rapids_sumdurationas...           4134
#
#                                                     Missing Percentage
# f_slp:fitbit_sleep_summary_rapids_avgefficiency...           36.739320
# f_slp:fitbit_sleep_summary_rapids_avgefficiency...           36.739320
# f_slp:fitbit_sleep_summary_rapids_sumdurationas...           36.041848
# f_slp:fitbit_sleep_summary_rapids_sumdurationas...           36.041848

# %%
target_col = 'f_slp:fitbit_sleep_summary_rapids_sumdurationasleepmain_norm:allday'
